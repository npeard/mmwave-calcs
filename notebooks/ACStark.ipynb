# %%
import sys
sys.path.append('../')
# %load_ext autotime
# Out:
# time: 141 µs (started: 2024-11-05 15:41:09 -08:00)

# %%
import plotters.plot_ac_stark as pac
# Out:
# time: 1.83 s (started: 2024-11-05 15:41:09 -08:00)

# %%
pac.plot_Cs_ground_state_tweezer_shift()
# Out:
# time: 12.3 s (started: 2024-11-05 15:41:11 -08:00)

# %%
pac.plot_Cs_7p_tweezer_shift()
# Out:
# time: 28.9 s (started: 2024-11-05 15:41:24 -08:00)

# %%
pac.plot_Cs_Rydberg_local_address_shift(n=40)
# Out:
# time: 1min 41s (started: 2024-11-05 15:41:53 -08:00)

# %%
pac.plot_Cs_Rydberg_local_address_shift(n=41)
# Out:
# time: 1min 41s (started: 2024-11-05 15:44:06 -08:00)
