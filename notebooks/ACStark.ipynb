# %%
import sys
sys.path.append('../')
# %load_ext autotime
# Out:
# time: 95.7 µs (started: 2024-10-28 14:42:40 -07:00)

# %%
import plotters.plot_ac_stark as pac
# Out:
# time: 1.36 s (started: 2024-10-28 14:42:40 -07:00)

# %%
pac.plot_Cs_ground_state_tweezer_shift()
# Out:
# time: 12.4 s (started: 2024-10-28 14:42:41 -07:00)

# %%
pac.plot_Cs_7p_tweezer_shift()
# Out:
# time: 27 s (started: 2024-10-28 14:42:54 -07:00)
